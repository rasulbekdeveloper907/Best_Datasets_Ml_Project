# %%
import sys
import os
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\data_loader.log"

# Log fayli mavjud papka borligini tekshirish
os.makedirs(os.path.dirname(log_path), exist_ok=True)

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

# %% [markdown]
# | Drug        | Brand name | Species | Use        | Notes       |
# | ----------- | ---------- | ------- | ---------- | ----------- |
# | Amoxicillin | Clamoxyl   | Dog     | Antibiotic | Common use  |
# | Ketamine    | Ketavet    | Cat     | Anesthetic | Widely used |
# | ...         | ...        | ...     | ...        | ...         |

# %%
#!/usr/bin/env python3
"""
Drugs.com — Veterinary section scraper (1000 ta sahifa limit)
"""

import time
import csv
import os
import random
import string
import sys
import logging
from urllib.parse import urljoin
import urllib.robotparser as robotparser

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# --------------- Configuration ---------------
BASE = "https://www.drugs.com"
VET_BASE = "https://www.drugs.com/vet/"
OUTPUT_CSV = "drugs_com_vet_1000.csv"
CHECKPOINT = "drugs_com_vet_progress.txt"  # store visited URLs
USER_AGENTS = [
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 13_4) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.4 Safari/605.1.15",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
]
DELAY_MIN = 0.5
DELAY_MAX = 1.5
MAX_ITEMS = 1000  # limit to 1000 items
HEADLESS = True

SPECIES_PAGES = [
    ("dogs", "/vet/dogs-a.html"),
    ("cats", "/vet/cats-a.html"),
    ("horses", "/vet/horses-a.html"),
    ("dairy-cattle", "/vet/dairy-cattle-a.html"),
    ("beef-cattle", "/vet/beef-cattle-a.html"),
    ("poultry", "/vet/poultry-a.html"),
    ("swine", "/vet/swine-a.html"),
    ("goats", "/vet/goats-a.html"),
    ("sheep", "/vet/sheep-a.html"),
    ("exotic", "/vet/exotic-a.html"),
]

# --------------- Logging ---------------
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s: %(message)s")
logger = logging.getLogger("drugscom_vet_scraper")

# The rest of the code remains the same, only MAX_ITEMS changed to 1000
# ... [rest of the scraping code stays identical to previous version]


# --------------- Helper functions ---------------

def obeys_robots(target_url, user_agent="*"):
    """Check robots.txt for allowed access to target_url."""
    rp = robotparser.RobotFileParser()
    rp.set_url(urljoin(BASE, "/robots.txt"))
    try:
        rp.read()
    except Exception as e:
        logger.warning("Could not read robots.txt: %s", e)
        return False
    return rp.can_fetch(user_agent, target_url)


def random_delay():
    time.sleep(random.uniform(DELAY_MIN, DELAY_MAX))


def ensure_output():
    header = ["Drug", "Brand name", "Species", "Use", "Notes", "Source URL"]
    if not os.path.exists(OUTPUT_CSV):
        with open(OUTPUT_CSV, "w", newline='', encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(header)


def load_checkpoint():
    seen = set()
    if os.path.exists(CHECKPOINT):
        with open(CHECKPOINT, "r", encoding="utf-8") as f:
            for line in f:
                seen.add(line.strip())
    return seen


def save_checkpoint(url):
    with open(CHECKPOINT, "a", encoding="utf-8") as f:
        f.write(url + "\n")


# --------------- Selenium setup ---------------

def make_driver(headless=True, user_agent=None):
    opts = Options()
    if headless:
        opts.add_argument("--headless=new")
    opts.add_argument("--disable-gpu")
    opts.add_argument("--no-sandbox")
    opts.add_argument("--window-size=1200,900")
    if user_agent:
        opts.add_argument(f"--user-agent={user_agent}")
    # optional: reduce image loading to save bandwidth
    prefs = {"profile.managed_default_content_settings.images": 2}
    opts.add_experimental_option("prefs", prefs)

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=opts)
    driver.set_page_load_timeout(60)
    return driver


# --------------- Parsing helpers ---------------

def parse_index_page(html, species_name):
    """Parse an AZ index page to extract product links.
    Drugs.com index pages list product names as <ul>/<li> or <div class="contentBox"> links.
    Selector logic may need adjustment if website changes.
    Returns list of absolute URLs.
    """
    soup = BeautifulSoup(html, "html.parser")
    links = []

    # Try common containers — this is resilient but may need tuning
    for a in soup.select("#content a, .contentBox a, .azindex a"):
        href = a.get('href')
        if not href:
            continue
        # skip anchors and javascript
        if href.startswith('#') or href.startswith('javascript:'):
            continue
        # product pages tend to contain '/vet/' and end with '.html' or product slug
        if '/vet/' in href or '/drug/' in href or href.startswith('/vet'):
            full = urljoin(BASE, href)
            links.append(full)

    # deduplicate
    return list(dict.fromkeys(links))


def parse_product_page(html, source_url, species_hint=None):
    """Extract Drug, Brand name, Species, Use, Notes from a product page HTML."""
    soup = BeautifulSoup(html, "html.parser")
    text = soup.get_text(separator=" ", strip=True)

    # Drug name: try <h1>
    drug = None
    h1 = soup.find('h1')
    if h1:
        drug = h1.get_text(strip=True)

    # Brand names: search for 'Brand names' or small descriptors
    brand = None
    brand_label = soup.find(string=lambda s: s and 'Brand name' in s or s and 'Brand names' in s)
    if brand_label:
        # parent paragraph likely contains the content
        parent = brand_label.parent
        brand = parent.get_text(separator=' ', strip=True).replace('Brand names:', '').replace('Brand name:', '').strip()

    # Species: some pages include a species header or list. Fall back to species_hint
    species = species_hint or ''
    species_candidates = []
    # try to locate an info box
    for strong in soup.select('strong'):
        txt = strong.get_text(strip=True)
        if 'Species' in txt:
            # grab next sibling text
            nxt = strong.next_sibling
            if nxt:
                species_candidates.append(str(nxt).strip())
    if not species_candidates:
        # heuristic: look for known species words
        for word in ['Dog', 'Cat', 'Horse', 'Cattle', 'Sheep', 'Goat', 'Pig', 'Poultry', 'Bird', 'Rabbit']:
            if word.lower() in text.lower():
                species_candidates.append(word)
    if species_candidates:
        species = ", ".join(dict.fromkeys([s for s in species_candidates if s]))

    # Use (indication) — try headings
    use = None
    for header_text in ['Uses', 'Indications', 'Indicated for', 'Indication']:
        h = soup.find(lambda tag: tag.name in ['h2', 'h3'] and tag.get_text(strip=True).startswith(header_text))
        if h:
            p = h.find_next('p')
            if p:
                use = p.get_text(separator=' ', strip=True)
                break
    if not use:
        # fallback: look for 'used to' pattern
        idx = text.lower().find('used to')
        if idx != -1:
            use = text[idx: idx+200]

    # Notes / side effects / comments
    notes = None
    for header_text in ['Side effects', 'Adverse reactions', 'Notes', 'Cautions', 'Warnings']:
        h = soup.find(lambda tag: tag.name in ['h2', 'h3'] and header_text.lower() in tag.get_text(strip=True).lower())
        if h:
            p = h.find_next('p')
            if p:
                notes = p.get_text(separator=' ', strip=True)
                break

    return {
        'Drug': drug,
        'Brand name': brand,
        'Species': species,
        'Use': use,
        'Notes': notes,
        'Source URL': source_url,
    }


# --------------- Main crawl logic ---------------

def main():
    logger.info('Starting Drugs.com veterinary scraper')

    # quick robots.txt check on the base section
    if not obeys_robots(VET_BASE, user_agent='*'):
        logger.error('robots.txt disallows scraping %s — aborting. Check site policy.', VET_BASE)
        sys.exit(1)

    ensure_output()
    seen = load_checkpoint()
    logger.info('Already-seen URLs loaded: %d', len(seen))

    driver = make_driver(headless=HEADLESS, user_agent=random.choice(USER_AGENTS))

    total_saved = 0
    try:
        for species_key, species_path in SPECIES_PAGES:
            # iterate A-Z index letters — drugs.com uses paths like /vet/dogs-a.html .. -z
            for letter in list(string.ascii_lowercase):
                idx_url = urljoin(BASE, species_path.replace('-a', f'-{letter}'))
                logger.info('Fetching index: %s (species: %s)', idx_url, species_key)

                if not obeys_robots(idx_url, user_agent='*'):
                    logger.warning('Blocked by robots.txt: %s - skipping', idx_url)
                    continue

                try:
                    driver.get(idx_url)
                except Exception as e:
                    logger.warning('Failed to load %s: %s', idx_url, e)
                    continue

                random_delay()

                links = parse_index_page(driver.page_source, species_key)
                logger.info('Found %d candidate links on index %s', len(links), idx_url)

                for link in links:
                    if total_saved >= MAX_ITEMS:
                        logger.info('Reached MAX_ITEMS=%d - finishing', MAX_ITEMS)
                        return
                    if link in seen:
                        continue

                    if not obeys_robots(link, user_agent='*'):
                        logger.debug('Link disallowed by robots: %s', link)
                        seen.add(link)
                        save_checkpoint(link)
                        continue

                    # fetch product page
                    try:
                        driver.get(link)
                    except Exception as e:
                        logger.warning('Failed to open product %s: %s', link, e)
                        seen.add(link)
                        save_checkpoint(link)
                        continue

                    random_delay()

                    item = parse_product_page(driver.page_source, link, species_hint=species_key.capitalize())

                    # write to CSV
                    with open(OUTPUT_CSV, 'a', newline='', encoding='utf-8') as f:
                        writer = csv.writer(f)
                        writer.writerow([item.get('Drug'), item.get('Brand name'), item.get('Species'), item.get('Use'), item.get('Notes'), item.get('Source URL')])

                    seen.add(link)
                    save_checkpoint(link)
                    total_saved += 1

                    logger.info('[%d] Saved: %s', total_saved, item.get('Drug'))

                    # small backoff
                    random_delay()

    finally:
        driver.quit()
        logger.info('Driver closed. Total saved: %d', total_saved)


if __name__ == '__main__':
    main()
# Out:
# 2025-11-06 14:11:41,563 INFO: Starting Drugs.com veterinary scraper
# 2025-11-06 14:11:42,039 INFO: Already-seen URLs loaded: 0
# 2025-11-06 14:11:42,040 INFO: ====== WebDriver manager ======
# 2025-11-06 14:11:43,153 INFO: Get LATEST chromedriver version for google-chrome
# 2025-11-06 14:11:43,854 INFO: Get LATEST chromedriver version for google-chrome
# 2025-11-06 14:11:44,571 INFO: Driver [C:\Users\Rasulbek907\.wdm\drivers\chromedriver\win64\142.0.7444.61\chromedriver-win32/chromedriver.exe] found in cache
# 2025-11-06 14:11:45,725 INFO: Fetching index: https://www.drugs.com/vet/dogs-a.html (species: dogs)
html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:09:23,813 WARNING: Failed to open product https://www.drugs.com/vet/levafen-carprofen-injection.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:11:24,438 WARNING: Failed to open product https://www.drugs.com/vet/librela.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:13:25,050 WARNING: Failed to open product https://www.drugs.com/vet/librela-10-mg-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:15:26,007 WARNING: Failed to open product https://www.drugs.com/vet/librela-15-mg-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:17:18,490 INFO: [381] Saved: Librela 20 mg (Canada)
# 2025-11-06 19:17:22,864 INFO: [382] Saved: Librela 30 mg (Canada)
# 2025-11-06 19:17:28,152 INFO: [383] Saved: Librela 5 mg (Canada)
# 2025-11-06 19:17:32,584 INFO: [384] Saved: Lido-2 (Canada)
# 2025-11-06 19:17:36,458 INFO: [385] Saved: Lidocaine 2% Injection
# 2025-11-06 19:17:41,160 INFO: [386] Saved: Lidocaine HCl 2% Injection
# 2025-11-06 19:17:46,172 INFO: [387] Saved: Lidocaine Hydrochloride 2%
# 2025-11-06 19:17:51,175 INFO: [388] Saved: Lidocaine Hydrochloride 2% with Epinephrine 1:100,000 (Canada)
# 2025-11-06 19:17:54,846 INFO: [389] Saved: Lidocaine Hydrochloride Injectable-2%
# 2025-11-06 19:17:58,429 INFO: [390] Saved: Lidocaine Injectable
# 2025-11-06 19:18:02,662 INFO: [391] Saved: Life Data Breeder's Formula
# 2025-11-06 19:18:07,791 INFO: [392] Saved: Light Mineral Oil, NF (Canada)
# 2025-11-06 19:20:08,819 WARNING: Failed to open product https://www.drugs.com/vet/lime-sulfur-dip.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:22:09,481 WARNING: Failed to open product https://www.drugs.com/vet/linco-spectin-sterile-solution-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:24:10,113 WARNING: Failed to open product https://www.drugs.com/vet/lipo-form.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:26:10,715 WARNING: Failed to open product https://www.drugs.com/vet/lipo-form-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:28:11,351 WARNING: Failed to open product https://www.drugs.com/vet/liqui-carn-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:30:11,881 WARNING: Failed to open product https://www.drugs.com/vet/liqui-tinic-4x.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:32:12,521 WARNING: Failed to open product https://www.drugs.com/vet/liquicarn.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:34:13,252 WARNING: Failed to open product https://www.drugs.com/vet/liquid-biocell-pet-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:36:13,787 WARNING: Failed to open product https://www.drugs.com/vet/liquid-hepato-can.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:37:18,770 INFO: [393] Saved: Liquid Hepato Bacon Flavor
# 2025-11-06 19:37:22,584 INFO: [394] Saved: Liquid Hepato Chicken Flavor
# 2025-11-06 19:37:26,689 INFO: [395] Saved: Liquid Immuno (Canada)
# 2025-11-06 19:39:28,440 WARNING: Failed to open product https://www.drugs.com/vet/liquid-immuno-bacon-flavor.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)
# 2025-11-06 19:41:29,061 WARNING: Failed to open product https://www.drugs.com/vet/liquid-immuno-chicken-flavor.html: HTTPConnectionPool(host='localhost', port=7850): Read timed out. (read timeout=120)

# %%
#!/usr/bin/env python3
"""
Wikipedia'dan inson, veterinariya va o'simlik dorilarini to'plash
Natija: CSV fayl (nom, tavsif, ishlab chiqaruvchi, dozasi, manba)
"""

import re
import time
import requests
import pandas as pd
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from tqdm import tqdm

BASE = "https://en.wikipedia.org"
HEADERS = {"User-Agent": "Mozilla/5.0 (compatible; DrugScraperBot/1.0)"}

# --- 1. URL'lar ---
URLS = {
    "human": "https://en.wikipedia.org/wiki/List_of_drugs",
    "veterinary": "https://en.wikipedia.org/wiki/List_of_veterinary_drugs",
    "herbal": "https://en.wikipedia.org/wiki/List_of_medicinal_plants"
}

def get_url(url):
    try:
        r = requests.get(url, headers=HEADERS, timeout=20)
        r.raise_for_status()
        return r
    except Exception as e:
        print(f"[ERROR] {url}: {e}")
        return None

def parse_list_page(url):
    """Dori sahifalarining linklarini topadi"""
    r = get_url(url)
    if not r:
        return []
    soup = BeautifulSoup(r.text, "html.parser")
    results = []
    for li in soup.select("li a[href^='/wiki/']"):
        href = li["href"]
        if ":" in href:
            continue
        name = li.get_text(strip=True)
        if len(name) < 2:
            continue
        full_url = urljoin(BASE, href)
        results.append((name, full_url))
    # unique
    seen = set()
    uniq = []
    for n, u in results:
        if u not in seen:
            uniq.append((n, u))
            seen.add(u)
    return uniq

def parse_drug_page(url):
    """Har bir dori sahifasidan tavsif, ishlab chiqaruvchi, doza oladi"""
    r = get_url(url)
    if not r:
        return {"Description": "", "Manufacturer": "", "Dosage": ""}
    soup = BeautifulSoup(r.text, "html.parser")
    desc = ""
    content = soup.find("div", {"class": "mw-parser-output"})
    if content:
        p = content.find("p")
        if p:
            desc = p.get_text(" ", strip=True)
    manu = ""
    dose = ""
    infobox = soup.find("table", {"class": re.compile("infobox")})
    if infobox:
        for row in infobox.find_all("tr"):
            header = row.find("th")
            value = row.find("td")
            if not value:
                continue
            label = header.get_text(" ", strip=True).lower() if header else ""
            val = value.get_text(" ", strip=True)
            if "manufact" in label or "developer" in label:
                manu = val
            if "dosage" in label or "routes" in label or "strength" in label:
                dose = val
    return {"Description": desc, "Manufacturer": manu, "Dosage": dose}

def collect_category(category_name, url, limit=None):
    """Kategoriya bo‘yicha dori ma’lumotlarini yig‘adi"""
    items = parse_list_page(url)
    if limit:
        items = items[:limit]
    records = []
    print(f"📦 {category_name.upper()} kategoriyada {len(items)} ta dori topildi")
    for name, href in tqdm(items, desc=f"{category_name} drugs"):
        info = parse_drug_page(href)
        records.append({
            "Category": category_name,
            "Name": name,
            "Description": info["Description"],
            "Manufacturer": info["Manufacturer"],
            "Dosage": info["Dosage"],
            "Source": href
        })
        time.sleep(0.2)
    return records

def main():
    all_records = []
    # --- Bu yerda qaysi turdagi dorilarni yig‘ish kerakligini tanla ---
    all_records += collect_category("human", URLS["human"], limit=300)         # Inson dorilari
    all_records += collect_category("veterinary", URLS["veterinary"], limit=300)  # Veterinariya dorilari
    all_records += collect_category("herbal", URLS["herbal"], limit=300)       # O‘simlik dorilari

    df = pd.DataFrame(all_records)
    df.to_csv("wikipedia_drugs_full.csv", index=False, encoding="utf-8")
    print(f"\n✅ {len(df)} ta dori ma'lumotlari saqlandi: wikipedia_drugs_full.csv")

if __name__ == "__main__":
    main()
# Out:
# 📦 HUMAN kategoriyada 75 ta dori topildi
# human drugs: 100%|██████████| 75/75 [02:08<00:00,  1.72s/it]
# 📦 VETERINARY kategoriyada 198 ta dori topildi
# veterinary drugs: 100%|██████████| 198/198 [05:21<00:00,  1.62s/it]
# 📦 HERBAL kategoriyada 300 ta dori topildi
# herbal drugs: 100%|██████████| 300/300 [07:50<00:00,  1.57s/it]
# ✅ 573 ta dori ma'lumotlari saqlandi: wikipedia_drugs_full.csv

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Notebooks\wikipedia_drugs_full.csv")

# %%
df.head()
# Out:
#   Category                               Name  \
# 0    human                          Main page
# 1    human                            Article
# 2    human  International nonproprietary name
# 3    human              British Approved Name
# 4    human         United States Adopted Name
#
#                                          Description Manufacturer Dosage  \
# 0  " Slug " is a song by Passengers, a side proje...          NaN    NaN
# 1  There are many hundreds of thousands of possib...          NaN    NaN
# 2  An international nonproprietary name ( INN ) i...          NaN    NaN
# 3  A British Approved Name ( BAN ) is the officia...          NaN    NaN
# 4  A United States Adopted Name ( USAN ) is a uni...          NaN    NaN
#
#                                               Source
# 0            https://en.wikipedia.org/wiki/Main_Page
# 1       https://en.wikipedia.org/wiki/Lists_of_drugs
# 2  https://en.wikipedia.org/wiki/International_no...
# 3  https://en.wikipedia.org/wiki/British_Approved...
# 4  https://en.wikipedia.org/wiki/United_States_Ad...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      573 non-null    object
#  1   Name          573 non-null    object
#  2   Description   236 non-null    object
#  3   Manufacturer  1 non-null      object
#  4   Dosage        117 non-null    object
#  5   Source        573 non-null    object
# dtypes: object(6)
# memory usage: 27.0+ KB

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_tables(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/138.0.0.0 Safari/537.36"
    }

    resp = requests.get(url, headers=headers)
    resp.raise_for_status()  # 403 xatoni oldini olish uchun User-Agent qo'shildi
    soup = BeautifulSoup(resp.text, 'html.parser')

    tables = soup.find_all('table', {'class': 'wikitable'})
    all_dfs = []
    for idx, table in enumerate(tables):
        df = pd.read_html(str(table))[0]
        caption = table.find('caption')
        if caption:
            df.attrs['caption'] = caption.get_text().strip()
        df.attrs['table_index'] = idx
        all_dfs.append(df)
    return all_dfs

if __name__ == '__main__':
    url = 'https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research'
    tables = scrape_tables(url)

    print(f"Topilgan jadval soni: {len(tables)}")
    for i, df in enumerate(tables):
        print("\n====================================")
        print(f"Jadval {i} — caption:", df.attrs.get('caption'))
        print(df.head())

    # Excel faylga saqlash
    with pd.ExcelWriter('wikipedia_datasets_tables.xlsx') as writer:
        for i, df in enumerate(tables):
            sheet_name = f"table_{i}"
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    print("Excel faylga saqlandi: wikipedia_datasets_tables.xlsx")
# Out:
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\Rasulbek907\AppData\Local\Temp\ipykernel_9812\3872863853.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# Topilgan jadval soni: 40
#
# ====================================
# Jadval 0 — caption: None
#                 Type                                           Subtypes
# 0  Specific category  Finance, Economics, Commerce, Societal, Health...
# 1              Scope  Supranational Union, National, Subnational, Mu...
# 2           Language  Mandarin Chinese, Spanish, English, Arabic, Hi...
# 3               Type          Tabular, Graph, Text, Image, Sound, Video
# 4              Usage                  Training, validating, and testing
#
# ====================================
# Jadval 1 — caption: None
#                                       Portal-name License  \
# 0  Comprehensive Knowledge Archive Network (CKAN)    AGPL
# 1                                            DKAN     GPL
# 2                                       Dataverse  Apache
# 3                                          DSpace     BSD
# 4                                          OpenML     BSD
#
#                  List of installations of the portal  \
# 0  https://ckan.github.io/ckan-instances/ https:/...
# 1                      https://getdkan.org/community
# 2  https://dataverse.org/installations https://da...
# 3                      https://registry.lyrasis.org/
# 4  https://www.openml.org/search?type=data&sort=r...
#
#                                       Typical usages
# 0  Data repository for government or non-profit o...
# 1  Data repository for government or non-profit o...
# 2   Data Management Solution for Research Institutes
# 3   Data Management Solution for Research Institutes
# 4  Data Management Solution to share datasets, al...
#
# ====================================
# Jadval 2 — caption: None
#                                     0  \
# 0                   Academic Torrents
# 1                     Amazon Datasets
# 2  Awesome Public Datasets Collection
# 3                          data.world
# 4             Datahub – Core Datasets
#
#                                                    1
# 0                       https://academictorrents.com
# 1                     https://registry.opendata.aws/
# 2  https://github.com/awesomedata/awesome-public-...
# 3       https://data.world/datasets/machine-learning
# 4                  https://datahub.io/docs/core-data
#
# ====================================
# Jadval 3 — caption: None
#                                    Dataset name  \
# 0                                 Netflix Prize
# 1                                Amazon reviews
# 2                       OpinRank Review Dataset
# 3                                     MovieLens
# 4  Yahoo! Music User Ratings of Musical Artists
#
#                                    Brief description    Preprocessing  \
# 0                          Movie ratings on Netflix.              NaN
# 1                US product reviews from Amazon.com.            None.
# 2  Reviews of cars and hotels from Edmunds.com an...            None.
# 3  22,000,000 ratings and 580,000 tags applied to...            None.
# 4        Over 10M ratings of artists by Yahoo users.  None described.
#
#                                            Instances        Format  \
# 0  100,480,507 ratings that 480,189 users gave to...  Text, rating
# 1                                      233.1 million          Text
# 2                     42,230 / ~259,000 respectively          Text
# 3                                              ~ 22M          Text
# 4                                              ~ 10M          Text
#
#                              Default task Created (updated) Reference  \
# 0                       Rating prediction              2006       [6]
# 1      Classification, sentiment analysis       2015 (2018)    [7][8]
# 2          Sentiment analysis, clustering              2011   [9][10]
# 3  Regression, clustering, classification              2016      [11]
# 4                  Clustering, regression              2004  [12][13]
#
#               Creator
# 0             Netflix
# 1      McAuley et al.
# 2   K. Ganesan et al.
# 3  GroupLens Research
# 4              Yahoo!
#
# ====================================
# Jadval 4 — caption: None
#                                Dataset name  \
# 0                              NYSK Dataset
# 1               The Reuters Corpus Volume 1
# 2               The Reuters Corpus Volume 2
# 3  Thomson Reuters Text Research Collection
# 4                   Saudi Newspapers Corpus
#
#                                    Brief description  \
# 0  English news articles about the case relating ...
# 1   Large corpus of Reuters news stories in English.
# 2  Large corpus of Reuters news stories in multip...
# 3                      Large corpus of news stories.
# 4                  31,030 Arabic newspaper articles.
#
#                                 Preprocessing Instances     Format  \
# 0       Filtered and presented in XML format.     10421  XML, text
# 1  Fine-grain categorization and topic codes.    810000       Text
# 2  Fine-grain categorization and topic codes.    487000       Text
# 3                      Details not described.   1800370       Text
# 4                         Metadata extracted.     31030       JSON
#
#                                 Default task  Created (updated) Reference  \
# 0       Sentiment analysis, topic extraction               2013      [25]
# 1  Classification, clustering, summarization               2002      [26]
# 2  Classification, clustering, summarization               2005      [27]
# 3  Classification, clustering, summarization               2009      [28]
# 4                  Summarization, clustering               2015      [29]
#
#                 Creator
# 0  Dermouche, M. et al.
# 1               Reuters
# 2               Reuters
# 3        T. Rose et al.
# 4            M. Alhagri
#
# ====================================
# Jadval 5 — caption: None
#                   Dataset name  \
# 0                 Enron Corpus
# 1            Ling-Spam Dataset
# 2  SMS Spam Collection Dataset
# 3    Twenty Newsgroups Dataset
# 4             Spambase Dataset
#
#                                    Brief description  \
# 0  Emails from employees at Enron organized into ...
# 1  Corpus containing both legitimate and spam ema...
# 2                       Collected SMS spam messages.
# 3             Messages from 20 different newsgroups.
# 4                                       Spam emails.
#
#                                        Preprocessing           Instances  \
# 0  Attachments removed, invalid email addresses c...           ~ 500,000
# 1  Four version of the corpus involving whether o...  2,412 Ham 481 Spam
# 2                                              None.                5574
# 3                                              None.               20000
# 4                      Many text features extracted.                4601
#
#   Format                          Default task Created (updated) Reference  \
# 0   Text  Network analysis, sentiment analysis       2004 (2015)  [37][38]
# 1   Text                        Classification              2000  [39][40]
# 2   Text                        Classification              2011  [41][42]
# 3   Text           Natural language processing              1999      [43]
# 4   Text        Spam detection, classification              1999      [44]
#
#                       Creator
# 0       Klimt, B. and Y. Yang
# 1  Androutsopoulos, J. et al.
# 2           T. Almeida et al.
# 3          T. Mitchell et al.
# 4           M. Hopkins et al.
#
# ====================================
# Jadval 6 — caption: None
#                             Dataset name  \
# 0                         MovieTweetings
# 1                            Twitter100k
# 2                           Sentiment140
# 3                    ASU Twitter Dataset
# 4  SNAP Social Circles: Twitter Database
#
#                                    Brief description  \
# 0  Movie rating dataset based on public and well-...
# 1                         Pairs of images and tweets
# 2  Tweet data from 2009 including original text, ...
# 3  Twitter network data, not actual tweets. Shows...
# 4                        Large Twitter network data.
#
#                                        Preprocessing  \
# 0                                                NaN
# 1                                                NaN
# 2  Classified using distant supervision from pres...
# 3                                              None.
# 4          Node features, circles, and ego networks.
#
#                                   Instances                           Format  \
# 0                                  ~710,000                             Text
# 1                                    100000                  Text and Images
# 2                                   1578627  Tweets, comma, separated values
# 3  11,316,811 users, 85,331,846 connections                             Text
# 4                                   1768149                             Text
#
#                  Default task  Created (updated) Reference             Creator
# 0  Classification, regression               2018      [45]            S. Dooms
# 1       Cross-media retrieval               2017  [46][47]       Y. Hu, et al.
# 2          Sentiment analysis               2009  [48][49]        A. Go et al.
# 3  Clustering, graph analysis               2009  [50][51]  R. Zafarani et al.
# 4  Clustering, graph analysis               2012  [52][53]   J. McAuley et al.
#
# ====================================
# Jadval 7 — caption: None
#                  Dataset name  \
# 0             NPS Chat Corpus
# 1       Twitter Triple Corpus
# 2               UseNet Corpus
# 3              NUS SMS Corpus
# 4  Reddit All Comments Corpus
#
#                                    Brief description  \
# 0         Posts from age-specific online chat rooms.
# 1              A-B-A triples extracted from Twitter.
# 2                             UseNet forum postings.
# 3  SMS messages collected between two users, with...
# 4                  All Reddit comments (as of 2015).
#
#                                        Preprocessing      Instances Format  \
# 0  Hand privacy masked, tagged for part of speech...      ~ 500,000    XML
# 1                                                NaN           4232   Text
# 2  Anonymized e-mails and URLs. Omitted documents...      7 billion   Text
# 3                                                NaN       ~ 10,000    XML
# 4                                                NaN  ~ 1.7 billion   JSON
#
#                     Default task  Created (updated) Reference  \
# 0  NLP, programming, linguistics               2007      [69]
# 1                            NLP               2016      [70]
# 2                            NaN               2011      [71]
# 3                            NLP               2011      [72]
# 4                  NLP, research               2015      [73]
#
#                                Creator
# 0  Forsyth, E., Lin, J., & Martell, C.
# 1                   Sordini, A. et al.
# 2            Shaoul, C., & Westbury C.
# 3                               KAN, M
# 4                  Stuck_In_the_Matrix
#
# ====================================
# Jadval 8 — caption: None
#              Dataset name                                  Brief description  \
# 0                 FreeLaw  Filtered data from Court Listener, part of the...
# 1             Pile of Law            Corpus of legal and administrative data
# 2  Caselaw Access Project  All official, book-published state and federal...
#
#                          Preprocessing    Instances Format  \
# 0          Cleaned and normalized text      4940710   Json
# 1  Cleaned, normalized, and privatized  ~50,000,000   Json
# 2          Cleaned and normalized text      ~10,000   Json
#
#                   Default task  Created (updated) Reference  \
# 0             NLP, linguistics               2020      [76]
# 1  NLP, linguistics, sentiment               2022  [77][78]
# 2             NLP, linguistics               2022      [79]
#
#                                              Creator
# 0                                           T. Hoppe
# 1  L. Zheng; N. Guha; B. Anderson; P. Henderson; ...
# 2  A. Aizman; S. Chapman; J. Cushman; K. Dulin; H...
#
# ====================================
# Jadval 9 — caption: None
#                             Dataset name  \
# 0                 Hansard French-English
# 1                 Web of Science Dataset
# 2                     Legal Case Reports
# 3              Blogger Authorship Corpus
# 4  Social Structure of Facebook Networks
#
#                                    Brief description  \
# 0                      The Canadian Hansard records.
# 1      Hierarchical Datasets for Text Classification
# 2  Federal Court of Australia cases from 2006 to ...
# 3    Blog entries of 19,320 people from blogger.com.
# 4  Large dataset of the social structure of Faceb...
#
#                                        Preprocessing  \
# 0                                                NaN
# 1                                              None.
# 2                                              None.
# 3  Blogger self-provided gender, age, industry, a...
# 4                                              None.
#
#                                            Instances  \
# 0  2869040 French-English sentence pairs in 46.3 ...
# 1                                              46985
# 2                                               4000
# 3                                             681288
# 4                               100 colleges covered
#
#                           Format  \
# 0  French-English sentence pairs
# 1                           Text
# 2                           Text
# 3                           Text
# 4                           Text
#
#                                         Default task Created (updated)  \
# 0                                        Translation              1995
# 1                     Classification, Categorization              2017
# 2                   Summarization, citation analysis              2012
# 3  Sentiment analysis, summarization, classification              2006
# 4                       Network analysis, clustering              2012
#
#   Reference            Creator
# 0      [80]     IBM, Bell labs
# 1  [81][82]  K. Kowsari et al.
# 2  [83][84]  F. Galgani et al.
# 3  [85][86]   J. Schler et al.
# 4  [87][88]    A. Traud et al.
#
# ====================================
# Jadval 10 — caption: None
#                           Dataset name  \
# 0                        Switchboard-1
# 1                              Hub5'00
# 2  Zero Resource Speech Challenge 2015
# 3             Parkinson Speech Dataset
# 4                 Spoken Arabic Digits
#
#                                    Brief description  \
# 0              Conversational speech over telephone.
# 1              Conversational speech over telephone.
# 2  Spontaneous speech (English), Read speech (Xit...
# 3  Multiple recordings of people with and without...
# 4   Spoken Arabic digits from 44 male and 44 female.
#
#                                        Preprocessing  \
# 0                                                NaN
# 1                                                NaN
# 2                               None, raw WAV files.
# 3  Voice features extracted, disease scored by ph...
# 4  Time-series of mel-frequency cepstrum coeffici...
#
#                                            Instances  \
# 0  260 hours of speech, from 543 speakers (302 ma...
# 1  260 hours of speech, from 543 speakers (302 ma...
# 2  English: 5h, 12 speakers; Xitsonga: 2h30, 24 s...
# 3                                               1040
# 4                                               8800
#
#                                               Format  \
# 0  audio, text transcript, word-level timestamps,...
# 1  audio, text transcript, word-level timestamps,...
# 2                                   WAV (audio only)
# 3                                               Text
# 4                                               Text
#
#                                         Default task Created (updated)  \
# 0        speech recognition, phonetic transcription.       1992 (2000)
# 1  speech recognition, phonetic transcription. Th...       1992 (2000)
# 2  Unsupervised discovery of speech features/subw...              2015
# 3                         Classification, regression              2013
# 4                                     Classification              2010
#
#     Reference             Creator
# 0  [120][121]                NIST
# 1  [120][121]                NIST
# 2  [122][123]    Versteegh et al.
# 3  [124][125]  B. E. Sakar et al.
# 4  [126][127]     M. Bedda et al.
#
# ====================================
# Jadval 11 — caption: None
#                           Dataset name  \
# 0  Geographic Origin of Music Data Set
# 1                 Million Song Dataset
# 2                              MUSDB18
# 3                   Free Music Archive
# 4          Bach Choral Harmony Dataset
#
#                                    Brief description  \
# 0  Audio features of music samples from different...
# 1   Audio features from one million different songs.
# 2               Multi-track popular music recordings
# 3  Audio under Creative Commons from 100k songs (...
# 4                               Bach chorale chords.
#
#                                       Preprocessing Instances     Format  \
# 0  Audio features extracted using MARSYAS software.      1059       Text
# 1                         Audio features extracted.        1M       Text
# 2                                         Raw audio       150   MP4, WAV
# 3                     Raw audio and audio features.    106574  Text, MP3
# 4                         Audio features extracted.      5665       Text
#
#                             Default task  Created (updated)   Reference  \
# 0  Geographic classification, clustering               2014  [140][141]
# 1             Classification, clustering               2011  [142][143]
# 2                      Source Separation               2017       [144]
# 3         Classification, recommendation               2017       [145]
# 4                         Classification               2014  [146][147]
#
#                     Creator
# 0            F. Zhou et al.
# 1  T. Bertin-Mahieux et al.
# 2           Z. Rafii et al.
# 3      M. Defferrard et al.
# 4       D. Radicioni et al.
#
# ====================================
# Jadval 12 — caption: None
#                      Dataset name  \
# 0                      UrbanSound
# 1                        AudioSet
# 2  Bird Audio Detection challenge
# 3   WSJ0 Hipster Ambient Mixtures
# 4                          Clotho
#
#                                    Brief description  \
# 0  Labeled sound recordings of sounds like air co...
# 1  10-second sound snippets from YouTube videos, ...
# 2  Audio from environmental monitoring stations, ...
# 3  Audio from WSJ0 mixed with noise recorded in t...
# 4  4,981 audio samples of 15 to 30 seconds long, ...
#
#                                        Preprocessing Instances  \
# 0  Sorted into folders by class of events as well...      1059
# 1       128-d PCA'd VGG-ish features every 1 second.   2084320
# 2                                                NaN   17,000+
# 3                  Noise clips matched to WSJ0 clips     28000
# 4                                                NaN     24905
#
#                                    Format                Default task  \
# 0                             Sound (WAV)              Classification
# 1  Text (CSV) and TensorFlow Record files              Classification
# 2                                     NaN              Classification
# 3                             Sound (WAV)     Audio source separation
# 4              Sound (WAV) and text (CSV)  Automated audio captioning
#
#   Created (updated)   Reference  \
# 0              2014  [148][149]
# 1              2017       [150]
# 2       2016 (2018)  [151][152]
# 3              2019       [153]
# 4              2020  [154][155]
#
#                                              Creator
# 0                                  J. Salamon et al.
# 1                          J. Gemmeke et al., Google
# 2  Queen Mary University and IEEE Signal Processi...
# 3              Wichern, G., et al., Whisper and MERL
# 4            K. Drossos, S. Lipping, and T. Virtanen
#
# ====================================
# Jadval 13 — caption: None
#                                   Dataset name  \
# 0                           Witty Worm Dataset
# 1  Cuff-Less Blood Pressure Estimation Dataset
# 2               Gas Sensor Array Drift Dataset
# 3                                Servo Dataset
# 4                     UJIIndoorLoc-Mag Dataset
#
#                                    Brief description  \
# 0  Dataset detailing the spread of the Witty worm...
# 1  Cleaned vital signals from human patients whic...
# 2  Measurements from 16 chemical sensors utilized...
# 3  Data covering the nonlinear relationships obse...
# 4  Indoor localization database to test indoor po...
#
#                                        Preprocessing            Instances  \
# 0  Split into a publicly available set and a rest...  55,909 IP addresses
# 1              125 Hz vital signs have been cleaned.                12000
# 2                Extensive number of features given.                13910
# 3  Levels of various components as a function of ...                  167
# 4                       Train and test splits given.                40000
#
#   Format                            Default task  Created (updated)  \
# 0   Text                          Classification               2004
# 1   Text              Classification, regression               2015
# 2   Text                          Classification               2012
# 3   Text                              Regression               1993
# 4   Text  Classification, regression, clustering               2015
#
#     Reference                                    Creator
# 0  [156][157]  Center for Applied Internet Data Analysis
# 1  [158][159]                          M. Kachuee et al.
# 2  [160][161]                                 A. Vergara
# 3  [162][163]                                 K. Ullrich
# 4  [164][165]                           D. Rambla et al.
#
# ====================================
# Jadval 14 — caption: None
#                                         Dataset name  \
# 0  Wearable Computing: Classification of Body Pos...
# 1                 Gesture Phase Segmentation Dataset
# 2             Vicon Physical Action Data Set Dataset
# 3                Daily and Sports Activities Dataset
# 4  Human Activity Recognition Using Smartphones D...
#
#                                    Brief description  \
# 0  People performing five standard actions while ...
# 1  Features extracted from video of people doing ...
# 2  10 normal and 10 aggressive physical actions t...
# 3  Motor sensor data for 19 daily and sports acti...
# 4  Gyroscope and accelerometer data from people w...
#
#                                        Preprocessing Instances Format  \
# 0                                              None.    165632   Text
# 1  Features extracted aim at studying gesture pha...      9900   Text
# 2            Many parameters recorded by 3D tracker.      3000   Text
# 3  Many sensors given, no preprocessing done on s...      9120   Text
# 4  Actions performed are labeled, all signals pre...     10299   Text
#
#                  Default task  Created (updated)   Reference  \
# 0              Classification               2013  [168][169]
# 1  Classification, clustering               2014  [170][171]
# 2              Classification               2011  [172][173]
# 3              Classification               2013  [174][175]
# 4              Classification               2012  [176][177]
#
#                                             Creator
# 0  Pontifical Catholic University of Rio de Janeiro
# 1                                     R. Madeo et a
# 2                                    T. Theodoridis
# 3                                 B. Barshan et al.
# 4                             J. Reyes-Ortiz et al.
#
# ====================================
# Jadval 15 — caption: None
#                           Dataset name  \
# 0                         Wine Dataset
# 1  Combined Cycle Power Plant Data Set
#
#                                    Brief description  \
# 0  Chemical analysis of wines grown in the same r...
# 1  Data from various sensors within a power plant...
#
#                           Preprocessing  Instances Format  \
# 0  13 properties of each wine are given        178   Text
# 1                                   NaN       9568   Text
#
#                  Default task  Created (updated)   Reference  \
# 0  Classification, regression               1991  [198][199]
# 1                  Regression               2014  [200][201]
#
#              Creator
# 0   M. Forina et al.
# 1  P. Tufekci et al.
#
# ====================================
# Jadval 16 — caption: None
#       Dataset name                                  Brief description  \
# 0    HIGGS Dataset  Monte Carlo simulations of particle accelerato...
# 1  HEPMASS Dataset  Monte Carlo simulations of particle accelerato...
#
#                               Preprocessing Instances Format    Default task  \
# 0  28 features of each collision are given.       11M   Text  Classification
# 1  28 features of each collision are given.  10500000   Text  Classification
#
#    Created (updated)        Reference      Creator
# 0               2014  [204][205][206]  D. Whiteson
# 1               2016  [205][206][207]  D. Whiteson
#
# ====================================
# Jadval 17 — caption: None
#                        Dataset name  \
# 0       Yacht Hydrodynamics Dataset
# 1  Robot Execution Failures Dataset
# 2        Pittsburgh Bridges Dataset
# 3                Automobile Dataset
# 4                  Auto MPG Dataset
#
#                                    Brief description  \
# 0             Yacht performance based on dimensions.
# 1  5 data sets that center around robotic failure...
# 2  Design description is given in terms of severa...
# 3  Data about automobiles, their insurance risk, ...
# 4                                 MPG data for cars.
#
#                                        Preprocessing  Instances Format  \
# 0             Six features are given for each yacht.        308   Text
# 1  Integer valued features such as torque and oth...        463   Text
# 2                 Various bridge features are given.        108   Text
# 3                            Car features extracted.        205   Text
# 4                  Eight features of each car given.        398   Text
#
#      Default task  Created (updated)   Reference                     Creator
# 0      Regression               2013  [208][209]                    R. Lopez
# 1  Classification               1999       [210]            L. Seabra et al.
# 2  Classification               1990  [211][212]             Y. Reich et al.
# 3      Regression               1987  [213][214]          J. Schimmer et al.
# 4      Regression               1993       [215]  Carnegie Mellon University
#
# ====================================
# Jadval 18 — caption: None
#                                       Dataset name  \
# 0  Volcanoes on Venus – JARtool experiment Dataset
# 1                    MAGIC Gamma Telescope Dataset
# 2                              Solar Flare Dataset
# 3                        CAMELS Multifield Dataset
#
#                                    Brief description  \
# 0  Venus images returned by the Magellan spacecraft.
# 1  Monte Carlo generated high-energy gamma partic...
# 2  Measurements of the number of certain types of...
# 3  2D maps and 3D grids from thousands of N-body ...
#
#                                        Preprocessing  \
# 0                      Images are labeled by humans.
# 1  Numerous features extracted from the simulations.
# 2      Many solar flare-specific features are given.
# 3  Each map and grid has 6 cosmological and astro...
#
#                               Instances                Format  \
# 0                             not given                Images
# 1                                 19020                  Text
# 2                                  1389                  Text
# 3  405,000 2D maps and 405,000 3D grids  2D maps and 3D grids
#
#                  Default task  Created (updated)   Reference  \
# 0              Classification               1991  [222][223]
# 1              Classification               2007  [223][224]
# 2  Regression, classification               1989       [225]
# 3                  Regression               2021       [226]
#
#                                 Creator
# 0                               M. Burl
# 1                               R. Bock
# 2                           G. Bradshaw
# 3  Francisco Villaescusa-Navarro et al.
#
# ====================================
# Jadval 19 — caption: None
#              Dataset name                                  Brief description  \
# 0  Volcanoes of the World  Volcanic eruption data for all known volcanic ...
# 1   Seismic-bumps Dataset               Seismic activities from a coal mine.
# 2               CAMELS-US  Catchment hydrology dataset with hydrometeorol...
# 3            CAMELS-Chile  Catchment hydrology dataset with hydrometeorol...
# 4           CAMELS-Brazil  Catchment hydrology dataset with hydrometeorol...
#
#                                        Preprocessing  Instances  \
# 0  Details such as region, subregion, tectonic se...       1535
# 1  Seismic activity was classified as hazardous o...       2584
# 2                                      see Reference        671
# 3                                      see Reference        516
# 4                                      see Reference        897
#
#                  Format                Default task  Created (updated)  \
# 0                  Text  Regression, classification               2013
# 1                  Text              Classification               2013
# 2  CSV, Text, Shapefile                  Regression               2017
# 3  CSV, Text, Shapefile                  Regression               2018
# 4  CSV, Text, Shapefile                  Regression               2020
#
#     Reference                             Creator
# 0       [227]                    E. Venzke et al.
# 1  [228][229]                    M. Sikora et al.
# 2  [230][231]  N. Addor et al. / A. Newman et al.
# 3       [232]          C. Alvarez-Garreton et al.
# 4       [233]                    V. Chagas et al.
#
# ====================================
# Jadval 20 — caption: None
#                                       Dataset name  \
# 0            Concrete Compressive Strength Dataset
# 1                      Concrete Slump Test Dataset
# 2                                     Musk Dataset
# 3                      Steel Plates Faults Dataset
# 4  Noble Metal Monometallic Nanoparticles Datasets
#
#                                    Brief description  \
# 0  Dataset of concrete properties and compressive...
# 1  Concrete slump flow given in terms of properties.
# 2  Predict if a molecule, given the features, wil...
# 3                 Steel plates of 7 different types.
# 4  Processing and structural features of monometa...
#
#                                        Preprocessing    Instances Format  \
# 0           Nine features are given for each sample.         1030   Text
# 1  Features of concrete given such as fly ash, wa...          103   Text
# 2              168 features given for each molecule.         6598   Text
# 3                 27 features given for each sample.         1941   Text
# 4             85-182 features given for each sample.  425 to 4000    CSV
#
#      Default task Created (updated)                            Reference  \
# 0      Regression              2007                          [237] [238]
# 1      Regression              2009                          [239] [240]
# 2  Classification              1994                                [241]
# 3  Classification              2010                                [242]
# 4      Regression      2017 to 2023  [243] [244] [245] [246] [247] [248]
#
#                       Creator
# 0                      I. Yeh
# 1                      I. Yeh
# 2  Arris Pharmaceutical Corp.
# 3     Semeion Research Center
# 4   A. Barnard and G. Opletal
#
# ====================================
# Jadval 21 — caption: None
#                     Dataset name  \
# 0                    Age Dataset
# 1  Synthetic Fundus Dataset[264]
# 2                   EEG Database
# 3         P300 Interface Dataset
# 4         Heart Disease Data Set
#
#                                    Brief description  \
# 0  A structured general-purpose dataset on life, ...
# 1  Photorealistic retinal images and vessel segme...
# 2  Study to examine EEG correlates of genetic pre...
# 3  Data from nine subjects collected using P300-b...
# 4  Attributed of patients with and without heart ...
#
#                                        Preprocessing  Instances  Format  \
# 0  A five-step method to infer birth and death ye...    1223009    Text
# 1  2500 images with 1500*1152 pixels useful for s...       2500  Images
# 2  Measurements from 64 electrodes placed on the ...        122    Text
# 3  Split into four sessions for each subject. MAT...       1224    Text
# 4  75 attributes given for each patient with some...        303    Text
#
#                    Default task  Created (updated)                Reference  \
# 0    Regression, Classification               2022  Paper[262] Dataset[263]
# 1  Classification, Segmentation               2020                    [265]
# 2                Classification               1999                    [266]
# 3                Classification               2008               [267][268]
# 4                Classification               1988               [269][270]
#
#               Creator
# 0  Amoradnejad et al.
# 1   C. Valenti et al.
# 2        H. Begleiter
# 3   U. Hoffman et al.
# 4    A. Janosi et al.
#
# ====================================
# Jadval 22 — caption: None
#                              Dataset name  \
# 0                         Abalone Dataset
# 1                             Zoo Dataset
# 2                    Demospongiae Dataset
# 3                       Farm animals data
# 4  Splice-junction Gene Sequences Dataset
#
#                                    Brief description  \
# 0  Physical measurements of Abalone. Weather patt...
# 1  Artificial dataset covering 7 classes of animals.
# 2                         Data about marine sponges.
# 3  PLF data inventory (cows, pigs; location, acce...
# 4  Primate splice-junction gene sequences (DNA) w...
#
#                                        Preprocessing  \
# 0                                              None.
# 1  Animals are classed into 7 categories and feat...
# 2  503 sponges in the Demosponge class are descri...
# 3                                  Labeled datasets.
# 4                                              None.
#
#                     Instances Format    Default task  Created (updated)  \
# 0                        4177   Text      Regression               1995
# 1                         101   Text  Classification               1990
# 2                         503   Text  Classification               2010
# 3  List is constantly updated   Text  Classification               2020
# 4                        3190   Text  Classification               1992
#
#   Reference                                 Creator
# 0     [296]  Marine Research Laboratories – Taroona
# 1     [297]                              R. Forsyth
# 2     [298]                      E. Armengol et al.
# 3     [299]                                V. Bloch
# 4     [275]                        G. Towell et al.
#
# ====================================
# Jadval 23 — caption: None
#                  Dataset name                        Brief description  \
# 0        UCI Mushroom Dataset  Mushroom attributes and classification.
# 1  Secondary Mushroom Dataset   Mushroom attributes and classification
#
#                                        Preprocessing  Instances Format  \
# 0        Many properties of each mushroom are given.       8124   Text
# 1  Simulated data from larger and more realistic ...      61069   Text
#
#      Default task  Created (updated)   Reference           Creator
# 0  Classification               1987       [302]      J. Schlimmer
# ...
#
#                     Preprocessing  Instances  \
# 0  This data is not pre-processed        NaN
# 1  This data is not pre-processed        NaN
# 2  This data is not pre-processed        NaN
# 3  This data is not pre-processed        NaN
# 4  This data is not pre-processed        NaN
#
#                                               Format  Default task  \
# 0      Direct link to reportsCurated list of reports           NaN
# 1                            Curated list of reports           NaN
# 2                     ReportsCurated list of reports           NaN
# 3                         Curated list of blog posts           NaN
# 4  Guides, case studies, blogs, and reports & sur...           NaN
#
#    Created (updated) Reference                Creator
# 0                NaN     [395]     TCFD Knowledge Hub
# 1                NaN     [396]  ResponsibilityReports
# 2                NaN     [397]                   IPCC
# 3                NaN     [398]                   ARCS
# 4                NaN     [399]           Mehra et al.
#
# ====================================
# Jadval 32 — caption: None
#                         Dataset name  \
# 0                          The Stack
# 1       LEMUR Neural Network Dataset
# 2                GitHub repositories
# 3     IBM Public GitHub repositories
# 4  RedHat Public GitHub repositories
#
#                                    Brief description  \
# 0  A 3.1 TB dataset consisting of permissively li...
# 1  The structured repository of standardized neur...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Preprocessing  \
# 0  Filtered through license detection and dedupli...
# 1  Filtered through license detection and dedupli...
# 2                     This data is not pre-processed
# 3                     This data is not pre-processed
# 4                     This data is not pre-processed
#
#                                            Instances  \
# 0  6 TB, 51.76B files (prior to deduplication); 3...
# 1                                    PyTorch models.
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Format  \
# 0                                            Parquet
# 1                                    Python scripts.
# 2  Curated lis of repositories from GitHub: 61 62...
# 3           Curated list of repositories from GitHub
# 4           Curated list of repositories from GitHub
#
#                                         Default task  Created (updated)  \
# 0  Language modeling, autocompletion, program syn...             2022.0
# 1  Image classification, object detection, image ...             2024.0
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#     Reference                                            Creator
# 0  [410][411]  D. Kocetkov, R. Li, L. Ben Allal, L. von Werra...
# 1       [412]  A. Goodarzi, R. Kochnev, W. Khalid, F. Qin, T....
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
# ====================================
# Jadval 33 — caption: None
#                            Dataset name  \
# 0                       Dow Jones Index
# 1  Statlog (Australian Credit Approval)
# 2                     eBay auction data
# 3          Statlog (German Credit Data)
# 4                Bank Marketing Dataset
#
#                                    Brief description  \
# 0  Weekly data of stocks from the first and secon...
# 1  Credit card applications either accepted or re...
# 2  Auction data from various eBay.com objects ove...
# 3  Binary credit classification into "good" or "b...
# 4  Data from a large marketing campaign carried o...
#
#                                        Preprocessing Instances  \
# 0  Calculated values included such as percentage ...       750
# 1  Attribute names are removed as well as identif...       690
# 2  Contains all bids, bidderID, bid times, and op...     ~ 550
# 3  Various financial features of each person are ...       690
# 4  Many attributes of the clients contacted are g...     45211
#
#                    Format                             Default task  \
# 0  Comma separated values  Classification, regression, Time series
# 1  Comma separated values                           Classification
# 2                    Text               Regression, classification
# 3                    Text                           Classification
# 4                    Text                           Classification
#
#    Created (updated)   Reference            Creator
# 0               2014  [419][420]    M. Brown et al.
# 1               1987  [421][422]         R. Quinlan
# 2               2012  [423][424]  G. Shmueli et al.
# 3               1994       [425]         H. Hofmann
# 4               2012  [426][427]     S. Moro et al.
#
# ====================================
# Jadval 34 — caption: None
#                                         Dataset name  \
# 0                                      Cloud DataSet
# 1                                    El Nino Dataset
# 2           Greenhouse Gas Observing Network Dataset
# 3  Atmospheric CO2 from Continuous Air Samples at...
# 4                                 Ionosphere Dataset
#
#                                    Brief description  \
# 0                  Data about 1024 different clouds.
# 1  Oceanographic and surface meteorological readi...
# 2  Time-series of greenhouse gas concentrations a...
# 3  Continuous air samples in Hawaii, USA. 44 year...
# 4  Radar data from the ionosphere. Task is to cla...
#
#                                       Preprocessing Instances Format  \
# 0                         Image features extracted.      1024   Text
# 1  12 weather attributes are measured at each buoy.    178080   Text
# 2                                             None.      2921   Text
# 3                                             None.  44 years   Text
# 4                        Many radar features given.       351   Text
#
#                  Default task  Created (updated)   Reference  \
# 0  Classification, clustering               1989       [433]
# 1                  Regression               1999       [434]
# 2                  Regression               2015       [435]
# 3                  Regression               2001       [436]
# 4              Classification               1989  [287][437]
#
#                                    Creator
# 0                               P. Collard
# 1  Pacific Marine Environmental Laboratory
# 2                                 D. Lucas
# 3                    Mauna Loa Observatory
# 4                 Johns Hopkins University
#
# ====================================
# Jadval 35 — caption: None
#             Dataset name                                  Brief description  \
# 0          Adult Dataset  Census data from 1994 containing demographic f...
# 1    Census-Income (KDD)  Weighted census data from the 1994 and 1995 Cu...
# 2  IPUMS Census Database  Census data from the Los Angeles and Long Beac...
# 3    US Census Data 1990                  Partial data from 1990 US census.
#
#                                        Preprocessing  Instances  \
# 0                            Cleaned and anonymized.      48842
# 1                 Split into training and test sets.     299285
# 2                                                NaN     256932
# 3  Results randomized and useful attributes selec...    2458285
#
#                    Format                Default task  Created (updated)  \
# 0  Comma separated values              Classification               1996
# 1  Comma separated values              Classification               2000
# 2                    Text  Classification, regression               1999
# 3                    Text  Classification, regression               1990
#
#     Reference                      Creator
# 0       [440]  United States Census Bureau
# 1  [441][442]  United States Census Bureau
# 2       [443]                        IPUMS
# 3       [444]  United States Census Bureau
#
# ====================================
# Jadval 36 — caption: None
#                         Dataset name  \
# 0               Bike Sharing Dataset
# 1       New York City Taxi Trip Data
# 2  Taxi Service Trajectory ECML PKDD
# 3                            METR-LA
# 4                               PeMS
#
#                                    Brief description  \
# 0  Hourly and daily count of rental bikes in a la...
# 1  Trip data for yellow and green taxis in New Yo...
# 2         Trajectories of all taxis in a large city.
# 3  Speed from loop detectors in the highway of Lo...
# 4  Speed, flow, occupancy and other metrics from ...
#
#                                        Preprocessing  \
# 0  Many features, including weather, length of tr...
# 1  Gives pick up and drop off locations, fares, a...
# 2  Many features given, including start and stop ...
# 3              Average speed in 5 minutes timesteps.
# 4  Metric usually aggregated via Average into 5 m...
#
#                                            Instances                  Format  \
# 0                                              17389                    Text
# 1                                            6 years                    Text
# 2                                            1710671                    Text
# 3    7,094,304 from 207 sensors and 34,272 timesteps  Comma separated values
# 4  39,000 individual detectors, each containing y...  Comma separated values
#
#                                         Default task   Created (updated)  \
# 0                                         Regression                2013
# 1                         Classification, clustering                2015
# 2                       Clustering, causal-discovery                2015
# 3                            Regression, Forecasting                2014
# 4  Regression, Forecasting, Nowcasting, Interpola...  (updated realtime)
#
#     Reference                                      Creator
# 0  [445][446]                                  H. Fanaee-T
# 1       [447]  New York City Taxi and Limousine Commission
# 2  [448][449]                           M. Ferreira et al.
# 3       [450]                              Jagadish et al.
# 4       [451]      California Department of Transportation
#
# ====================================
# Jadval 37 — caption: None
#                       Dataset name  \
# 0  Webpages from Common Crawl 2012
# 1  Internet Advertisements Dataset
# 2           Internet Usage Dataset
# 3                      URL Dataset
# 4        Phishing Websites Dataset
#
#                                    Brief description  \
# 0  Large collection of webpages and how they are ...
# 1  Dataset for predicting if a given image is an ...
# 2            General demographics of internet users.
# 3      120 days of URL data from a large conference.
# 4                      Dataset of phishing websites.
#
#                                        Preprocessing Instances Format  \
# 0                                              None.      3.5B   Text
# 1  Features encode geometry of ads and phrases oc...      3279   Text
# 2                                              None.     10104   Text
# 3               Many features of each URL are given.   2396130   Text
# 4              Many features of each site are given.      2456   Text
#
#                  Default task  Created (updated)   Reference  \
# 0  clustering, classification               2013       [452]
# 1              Classification               1998  [453][454]
# 2  Classification, clustering               1999       [455]
# 3              Classification               2009  [456][457]
# 4              Classification               2015       [458]
#
#              Creator
# 0       V. Granville
# 1      N. Kushmerick
# 2            D. Cook
# 3              J. Ma
# 4  R. Mustafa et al.
#
# ====================================
# Jadval 38 — caption: None
#                               Dataset name  \
# 0                       Poker Hand Dataset
# 1                        Connect-4 Dataset
# 2       Chess (King-Rook vs. King) Dataset
# 3  Chess (King-Rook vs. King-Pawn) Dataset
# 4              Tic-Tac-Toe Endgame Dataset
#
#                                    Brief description  \
# 0         5 card hands from a standard 52 card deck.
# 1  Contains all legal 8-ply positions in the game...
# 2  Endgame Database for White King and Rook again...
# 3                  King+Rook versus King+Pawn on a7.
# 4  Binary classification for win conditions in ti...
#
#                                        Preprocessing  Instances Format  \
# 0  Attributes of each hand are given, including t...    1025010   Text
# 1                                              None.      67557   Text
# 2                                              None.      28056   Text
# 3                                              None.       3196   Text
# 4                                              None.        958   Text
#
#                  Default task  Created (updated)   Reference         Creator
# 0  Regression, classification               2007       [474]      R. Cattral
# 1              Classification               1995       [475]        J. Tromp
# 2              Classification               1994  [476][477]  M. Bain et al.
# 3              Classification               1989       [478]        R. Holte
# 4              Classification               1991       [479]          D. Aha
#
# ====================================
# Jadval 39 — caption: None
#                                     Dataset name  \
# 0                               Housing Data Set
# 1                         The Getty Vocabularies
# 2  Yahoo! Front Page Today Module User Click Log
# 3              British Oceanographic Data Centre
# 4           Congressional Voting Records Dataset
#
#                                    Brief description  \
# 0  Median home values of Boston with associated h...
# 1  structured terminology for art and other mater...
# 2  User click log for news articles displayed in ...
# 3  Biological, chemical, physical and geophysical...
# 4  Voting data for all USA representatives on 16 ...
#
#                                        Preprocessing  \
# 0                                              None.
# 1                                              None.
# 2           Conjoint analysis with a bilinear model.
# 3                                           Various.
# 4  Beyond the raw voting data, various other feat...
#
#                        Instances Format            Default task  \
# 0                            506   Text              Regression
# 1                          large   Text          Classification
# 2         45,811,883 user visits   Text  Regression, clustering
# 3  22K variables, many instances   Text  Regression, clustering
# 4                            435   Text          Classification
#
#    Created (updated)   Reference                            Creator
# 0               1993       [480]                 D. Harrison et al.
# 1               2015       [481]                       Getty Center
# 2               2009  [482][483]                         Chu et al.
# 3               2015       [484]  British Oceanographic Data Centre
# 4               1987       [485]                       J. Schlimmer
# Excel faylga saqlandi: wikipedia_datasets_tables.xlsx

# %%
import pandas as pd 
df = pd.read_excel(r"C:\Users\Rasulbek907\Desktop\Project_MP\Notebooks\wikipedia_datasets_tables.xlsx")

# %%
df.head()
# Out:
#                 Type                                           Subtypes
# 0  Specific category  Finance, Economics, Commerce, Societal, Health...
# 1              Scope  Supranational Union, National, Subnational, Mu...
# 2           Language  Mandarin Chinese, Spanish, English, Arabic, Hi...
# 3               Type          Tabular, Graph, Text, Image, Sound, Video
# 4              Usage                  Training, validating, and testing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      13 non-null     object
#  1   Subtypes  13 non-null     object
# dtypes: object(2)
# memory usage: 340.0+ bytes

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

def scrape_text_data_section(url, output_dir="text_data_tables", to_csv=False, to_excel=True):
    # Oddiy ASCII User-Agent
    headers = {
        "User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                       "AppleWebKit/537.36 (KHTML, like Gecko) "
                       "Chrome/138.0.0.0 Safari/537.36")
    }
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, 'html.parser')

    # “Text data” bo‘limini topish
    span_tag = soup.find('span', {'class': 'mw-headline', 'id': 'Text_data'})
    if not span_tag:
        print("“Text data” bo‘limi topilmadi!")
        return

    h2_tag = span_tag.find_parent('h2')
    if not h2_tag:
        print("Sarlavha tagi h2 ichida topilmadi!")
        return

    # Bo‘limdan keyingi jadvallarni olish
    tables = []
    for sib in h2_tag.find_next_siblings():
        if sib.name == 'h2':
            break
        if sib.name == 'table' and 'wikitable' in sib.get('class', []):
            df = pd.read_html(str(sib))[0]
            tables.append(df)

    print(f"Topilgan jadvallar soni: {len(tables)}")

    if not tables:
        print("Hech qanday jadval topilmadi.")
        return

    os.makedirs(output_dir, exist_ok=True)

    for idx, df in enumerate(tables):
        fname = f"table_{idx+1}"
        if to_csv:
            csv_path = os.path.join(output_dir, fname + ".csv")
            df.to_csv(csv_path, index=False, encoding='utf-8-sig')  # UTF-8 encoding qo‘shildi
            print(f"CSV saqlandi: {csv_path}")
        if to_excel:
            excel_path = os.path.join(output_dir, fname + ".xlsx")
            df.to_excel(excel_path, index=False)
            print(f"Excel saqlandi: {excel_path}")

    if to_excel:
        all_excel = os.path.join(output_dir, "all_tables.xlsx")
        with pd.ExcelWriter(all_excel) as writer:
            for idx, df in enumerate(tables):
                sheet_name = f"Table_{idx+1}"
                df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"Barcha jadvallar bir faylga saqlandi: {all_excel}")


if __name__ == "__main__":
    url = "https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning-research"
    scrape_text_data_section(url, output_dir="text_data_tables", to_csv=True, to_excel=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[23], line 67
#      65 if __name__ == "__main__":
#      66     url = "https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning-research"
# ---> 67     scrape_text_data_section(url, output_dir="text_data_tables", to_csv=True, to_excel=True)
#
# Cell In[23], line 14, in scrape_text_data_section(url, output_dir, to_csv, to_excel)
#       8 headers = {
#       9     "User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#      10                    "AppleWebKit/537.36 (KHTML, like Gecko) "
#      11                    "Chrome/138.0.0.0 Safari/537.36")
#      12 }
#      13 resp = requests.get(url, headers=headers)
# ---> 14 resp.raise_for_status()
#      15 soup = BeautifulSoup(resp.text, 'html.parser')
#      17 # “Text data” bo‘limini topish
#
# File c:\Users\Rasulbek907\Desktop\Project_MP\mpvenv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning-research

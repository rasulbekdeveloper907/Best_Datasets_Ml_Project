# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\data_loader.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Raw_Data\Raw_DF.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0            BMW Worldwide Sales Records (2010–2024)
# 1           1  Global Earthquake-Tsunami Risk Assessment Dataset
# 2           2                   Amazon Diwali Product Sales 2025
# 3           3              Students_Academic_Performance_Dataset
# 4           4             Social Media and Mental Health Balance
#
#                                             subtitle  \
# 0  A complete dataset of BMW cars from 2010–2024 ...
# 1  Seismic Features & Tsunami Classification Data...
# 2  Amazon Diwali Product Sales 2025 and Sentiment...
# 3  Insights into how background impacts students’...
# 4  Exploring corelations between daily screen hou...
#
#                                                 tags         creatorname  \
# 0  [{"ref": "business", "name": "business", "desc...   Ahmad Raza Kashif
# 1  [{"ref": "exploratory data analysis", "name": ...  Ahmed Mohamed Zaki
# 2  [{"ref": "clothing and accessories", "name": "...          Anand Shaw
# 3  [{"ref": "education", "name": "education", "de...         Sadia javed
# 4  [{"ref": "mental health", "name": "mental heal...        Ayesha Imran
#
#    viewcount  downloadcount           ownername  votecount
# 0      74939          22414   Ahmad Raza Kashif        436
# 1      87713          18977  Ahmed Mohamed Zaki        644
# 2       4604           1313          Anand Shaw         27
# 3       8573           2182         Sadia javed         53
# 4      12218           3086        Ayesha Imran         45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3000 non-null   int64
#  1   title          3000 non-null   object
#  2   subtitle       2747 non-null   object
#  3   tags           3000 non-null   object
#  4   creatorname    3000 non-null   object
#  5   viewcount      3000 non-null   int64
#  6   downloadcount  3000 non-null   int64
#  7   ownername      3000 non-null   object
#  8   votecount      3000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 211.1+ KB

# %%
import pandas as pd

# 1. CSV faylni o'qish (agar mavjud bo'lsa)
# df = pd.read_csv("file.csv")

# 2. Har bir ustun bo'yicha unikal elementlar sonini hisoblash
unique_counts = df.nunique().reset_index()
unique_counts.columns = ['Column', 'Unique_Count']

# 3. Natijani chiqarish
print(unique_counts)
# Out:
#           Column  Unique_Count
# 0     Unnamed: 0          3000
# 1          title          2930
# 2       subtitle          2730
# 3           tags          2533
# 4    creatorname          1984
# 5      viewcount          2839
# 6  downloadcount          2551
# 7      ownername          2020
# 8      votecount           709

# %%
import sys
import os

# Source papkasini yo'lga qo'shamiz
source_path = os.path.abspath("../Source")
if source_path not in sys.path:
    sys.path.append(source_path)

print("Python executable:", sys.executable)
print("Source path added:", source_path)

# Endi modulni import qilamiz
from preprosessing import Cleaner, Encoder, Scaler
# Out:
# Python executable: c:\Users\Rasulbek907\Desktop\Project_MP\mpvenv\Scripts\python.exe
# Source path added: c:\Users\Rasulbek907\Desktop\Project_MP\Source

# %%
cleaner = Cleaner(df).tozala()
df_clean = cleaner.get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3000 non-null   int64
#  1   title          3000 non-null   object
#  2   subtitle       3000 non-null   object
#  3   tags           3000 non-null   object
#  4   creatorname    3000 non-null   object
#  5   viewcount      3000 non-null   int64
#  6   downloadcount  3000 non-null   int64
#  7   ownername      3000 non-null   object
#  8   votecount      3000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 211.1+ KB

# %%
df.to_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Preprosessed\Missing_Value.csv")

# %%
encoder = Encoder(df_clean, target_col='y').encodla()
df_encoded = encoder.get_df()

# %%
df.info()

# %%
scaler = Scaler(df_encoded, target_col='y').scaling_qil()
df_scaled = scaler.get_df()

# %%
df.head()

# %%
df.to_csv(r"C:\Users\Rasulbek907\Desktop\Final_Project\Data\Preprosessed_data\Preprosessed.csv")
